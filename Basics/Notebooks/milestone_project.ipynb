# %%
game_board=[" "]*10

# %%
game_board[0]
# Out:
# ' '

# %%
game_board
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
game_board[1]='X'

# %%
game_board
# Out:
# [' ', 'X', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
